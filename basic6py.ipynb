# %%
#pandas
 #series
 #data frames

# %%
import pandas as pd
import numpy as np

# %%
data = np.array(['aaa','bbb','ccc'])
series1= pd.Series(data)
series1
# Out:
# 0    aaa
# 1    bbb
# 2    ccc
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series1.dtype
# Out:
# dtype('O')

# %%
series2=pd.Series([1,2,3,4,5])
series2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#dataframe
#METHOD 1 FROM KAGGGlE.com
df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220117%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220117T095007Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...',sep='\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape #no of rows and columns
# Out:
# (59, 7)

# %%
df.size
# Out:
# 413

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
df.isnull().sum() #to check for null values in df
#NaN-not a number
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
#df.dropna() if there is null value remove it

# %%
# METHOD 2
df=pd.read_table('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220117%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220117T095007Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...')
df

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
#METHOD 3-
df=pd.read_csv('/content/fruits_data_with_colors.txt',sep='\t')
df

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()#displays first 5 values
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.head(3)

# %%
df.tail()#last 5 values
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 54            4      lemon       unknown   116    6.1     8.5         0.71
# 55            4      lemon       unknown   116    6.3     7.7         0.72
# 56            4      lemon       unknown   116    5.9     8.1         0.73
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70

# %%
df.tail(2)
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70

# %%
df.fruit_name.unique() #unique elemnts in data frame
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
df.fruit_subtype.nunique() #give total number of unique name
# Out:
# 10

# %%
df.groupby('fruit_name',sort=False).size()#ecah element how many
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
df['fruit_name'].value_counts()
# Out:
# apple       19
# orange      19
# lemon       16
# mandarin     5
# Name: fruit_name, dtype: int64

# %%
df.columns
# Out:
# Index(['fruit_label', 'fruit_name', 'fruit_subtype', 'mass', 'width', 'height',
#        'color_score'],
#       dtype='object')
# Index(['fruit_label', 'fruit_name', 'fruit_subtype', 'mass', 'width', 'height',
#        'color_score'],
#       dtype='object')

# %%
df.describe()#values like count mean ie summary of statstics
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   59.000000  59.000000  59.000000    59.000000
# mean      2.542373  163.118644   7.105085   7.693220     0.762881
# std       1.208048   55.018832   0.816938   1.361017     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.000000   6.600000   7.200000     0.720000
# 50%       3.000000  158.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.000000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %%
import matplotlib.pyplot as plt

# %%
fname = df.fruit_name.unique()
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
type(fname)
# Out:
# pandas.core.series.Series

# %%
fsize =df.groupby('fruit_name',sort = False).size()
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
plt.bar(fname,fsize)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.scatter(df['height'],df['mass'],color='r')

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df[11:21]#slicing
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 11            1      apple          braeburn   172    7.1     7.6         0.92
# 12            1      apple          braeburn   154    7.0     7.1         0.88
# 13            1      apple  golden_delicious   164    7.3     7.7         0.70
# 14            1      apple  golden_delicious   152    7.6     7.3         0.69
# 15            1      apple  golden_delicious   156    7.7     7.1         0.69
# 16            1      apple  golden_delicious   156    7.6     7.5         0.67
# 17            1      apple  golden_delicious   168    7.5     7.6         0.73
# 18            1      apple       cripps_pink   162    7.5     7.1         0.83
# 19            1      apple       cripps_pink   162    7.4     7.2         0.85
# 20            1      apple       cripps_pink   160    7.5     7.5         0.86

# %%
#iloc #purely integer-locatiom based indexing for selection by position
x=df.iloc[11:21,1:6].values#convert to numpy array
x
# Out:
# array([['apple', 'braeburn', 172, 7.1, 7.6],
#        ['apple', 'braeburn', 154, 7.0, 7.1],
#        ['apple', 'golden_delicious', 164, 7.3, 7.7],
#        ['apple', 'golden_delicious', 152, 7.6, 7.3],
#        ['apple', 'golden_delicious', 156, 7.7, 7.1],
#        ['apple', 'golden_delicious', 156, 7.6, 7.5],
#        ['apple', 'golden_delicious', 168, 7.5, 7.6],
#        ['apple', 'cripps_pink', 162, 7.5, 7.1],
#        ['apple', 'cripps_pink', 162, 7.4, 7.2],
#        ['apple', 'cripps_pink', 160, 7.5, 7.5]], dtype=object)

# %%
x=df.iloc[:,1:6].values
x
# Out:
# array([['apple', 'granny_smith', 192, 8.4, 7.3],
#        ['apple', 'granny_smith', 180, 8.0, 6.8],
#        ['apple', 'granny_smith', 176, 7.4, 7.2],
#        ['mandarin', 'mandarin', 86, 6.2, 4.7],
#        ['mandarin', 'mandarin', 84, 6.0, 4.6],
#        ['mandarin', 'mandarin', 80, 5.8, 4.3],
#        ['mandarin', 'mandarin', 80, 5.9, 4.3],
#        ['mandarin', 'mandarin', 76, 5.8, 4.0],
#        ['apple', 'braeburn', 178, 7.1, 7.8],
#        ['apple', 'braeburn', 172, 7.4, 7.0],
#        ['apple', 'braeburn', 166, 6.9, 7.3],
#        ['apple', 'braeburn', 172, 7.1, 7.6],
#        ['apple', 'braeburn', 154, 7.0, 7.1],
#        ['apple', 'golden_delicious', 164, 7.3, 7.7],
#        ['apple', 'golden_delicious', 152, 7.6, 7.3],
#        ['apple', 'golden_delicious', 156, 7.7, 7.1],
#        ['apple', 'golden_delicious', 156, 7.6, 7.5],
#        ['apple', 'golden_delicious', 168, 7.5, 7.6],
#        ['apple', 'cripps_pink', 162, 7.5, 7.1],
# ...

# %%
x=df.iloc[:,-1]#negative indexing
x
# Out:
# 0     0.55
# 1     0.59
# 2     0.60
# 3     0.80
# 4     0.79
# 5     0.77
# 6     0.81
# 7     0.81
# 8     0.92
# 9     0.89
# 10    0.93
# 11    0.92
# 12    0.88
# 13    0.70
# 14    0.69
# 15    0.69
# 16    0.67
# 17    0.73
# 18    0.83
# 19    0.85
# 20    0.86
# 21    0.84
# 22    0.87
# 23    0.88
# 24    0.75
# 25    0.75
# 26    0.74
# 27    0.77
# 28    0.72
# 29    0.81
# 30    0.79
# 31    0.82
# 32    0.80
# 33    0.74
# 34    0.75
# 35    0.75
# 36    0.76
# 37    0.79
# 38    0.77
# 39    0.75
# 40    0.78
# 41    0.79
# 42    0.82
# 43    0.70
# 44    0.72
# 45    0.72
# 46    0.71
# 47    0.72
# 48    0.72
# 49    0.73
# 50    0.71
# 51    0.72
# 52    0.72
# 53    0.74
# 54    0.71
# 55    0.72
# 56    0.73
# 57    0.72
# 58    0.70
# Name: color_score, dtype: float64

# %%
x=df.iloc[:,[1,3,5]].values
x
# Out:
# array([['apple', 192, 7.3],
#        ['apple', 180, 6.8],
#        ['apple', 176, 7.2],
#        ['mandarin', 86, 4.7],
#        ['mandarin', 84, 4.6],
#        ['mandarin', 80, 4.3],
#        ['mandarin', 80, 4.3],
#        ['mandarin', 76, 4.0],
#        ['apple', 178, 7.8],
#        ['apple', 172, 7.0],
#        ['apple', 166, 7.3],
#        ['apple', 172, 7.6],
#        ['apple', 154, 7.1],
#        ['apple', 164, 7.7],
#        ['apple', 152, 7.3],
#        ['apple', 156, 7.1],
#        ['apple', 156, 7.5],
#        ['apple', 168, 7.6],
#        ['apple', 162, 7.1],
#        ['apple', 162, 7.2],
#        ['apple', 160, 7.5],
#        ['apple', 156, 7.4],
#        ['apple', 140, 7.1],
#        ['apple', 170, 7.9],
#        ['orange', 342, 9.4],
#        ['orange', 356, 9.2],
#        ['orange', 362, 9.2],
#        ['orange', 204, 9.2],
#        ['orange', 140, 7.1],
#        ['orange', 160, 7.4],
#        ['orange', 158, 7.5],
#        ['orange', 210, 8.0],
# ...
