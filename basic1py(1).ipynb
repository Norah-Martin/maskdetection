# %% [markdown]
# #file name extensions
# .c-c progrm
# .cpp-c++
# .java-java
# .js- java script
# .html- webpage-hypertext markup lam=nguage
# .css -cscading style shhers
# .txt -text
# .docx -word document
# .pptx - power point presentatiom
# .xlsx-power point worksheet
# .csv-comma seperated value
# .py-python file
# .ipynp-jupyter
# .tsv-tap seperate value
# .json-javascript object notation

# %%
a=1

# %%
b=2

# %%
type(a)
# Out:
# int

# %%
d=1.3

# %%
type(d)
# Out:
# float

# %%
b
# Out:
# 2

# %%
print(a)
# Out:
# 1

# %%
print(b)
# Out:
# 2

# %%
a
b
# only last value is printed
#for each value u shuld give print
# Out:
# 2

# %%
a,b
# Out:
# (1, 2)

# %%
print(a,b)
# Out:
# 1 2

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'int'>

# %%
c=3

# %%
d=1.3

# %%
e=True
f=False

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# print(type(e))
# print(type(f))

# %%
g='python'

# %%
type(g)
# Out:
# str

# %%
h="python"
#no much differnece between '' and""

# %%
type(h)
# Out:
# str

# %%
a1=2+8j

# %%
type(a1)
# Out:
# complex

# %%
a2=8+8j

#only j can be complex

# %%
print(a2)
# Out:
# (8+8j)

# %%
#input
b1=int(input("enter a number:"))
print(b1)
# Out:
# enter a number:2
# 2

# %%
b2=int(input("enter a number:"))
print(b2)
# Out:
# enter a number:5
# 5

# %%
b1+b2
#it does not add bcoz treat as string
# Out:
# 7

# %%
int(b1)-int(b2)
# Out:
# -3

# %%
#square
a=int(input("enter a number:"))
square = a * a
print("sqaure=",square)
# Out:
# enter a number:3
# sqaure= 9

# %%
a = "HELLO WORLD!"

# %%
type(a)
# Out:
# str

# %%
b = 'A'
#no character

# %%
type(b)
# Out:
# str

# %%
a + b #concatenate
# Out:
# 'HELLO WORLD!A'

# %%
a
# Out:
# 'HELLO WORLD!'

# %%
#INDEXING
a[0]
HELLO WORLD!
01234567891011
# Out:
#   File "<ipython-input-77-05c839384772>", line 3
#     HELLO WORLD!
#               ^
# SyntaxError: invalid syntax

# %%
a[0:4]#inlcusive:exclusive
# Out:
# 'HELL'

# %%
#raw string
#print("c:users\programfiles\newfolder")
print(r"c:users\programfiles\newfolder")#raw string
#special meaning like \n means newline will not be executed in  raw string
# Out:
# c:users\programfiles
# ewfolder
# c:users\programfiles\newfolder

# %%
a = int(input("enter num1:"))
b = int(input("enter num 2:"))
c = a + b
print(c)
print(f"the sum of{a} and {b}is" ,c)#formatted string
# Out:
# enter num1:2
# enter num 2:4
# 6
# the sum of2 and 4is 6

# %%
a=10

# %%
b = 2

# %%
a+b
# Out:
# 12

# %%
a-b
# Out:
# 8

# %%
a/b
# Out:
# 5.0

# %%
a//b #floor division
# Out:
# 5

# %%
a % b #modular division
# Out:
# 0

# %%
#round(for even number one less and odd next didgit)
#floor(previous value)
#ceil(next value)

# %%
x = 14.78
round(x)
# Out:
# 15

# %%
x = 14.24
round(x)
# Out:
# 14

# %%
x = 14.5
round(x)
# Out:
# 14

# %%
#math library
import math
math.floor(14.78)
# Out:
# 14

# %%
math.floor(14.28)
# Out:
# 14

# %%
math.ceil(14.78)
# Out:
# 15

# %%
math.ceil(14.28)
# Out:
# 15
